# %% [markdown]
# # Bayesian models

# %% [markdown]
# In this seminar:
#
# * Make sure all the dependencies are installed and work fine for you
# * Look into the lecture example

# %% [markdown]
# ## Installation
# 1. Install [Anaconda](https://www.anaconda.com/) or [Mamba](https://github.com/mamba-org/mamba)
#
#     * Conda is slow
#     * Mamba is fast (I use this one)
#
# 2. Create an environment for the course
#
# ```console
# conda env update -f environment.yaml
# ```
#
# You can find the environment file in the root of the repository
#
# 3. Install jupyter kernel for the course
#
# ```
# conda activate bayes-econ
# python -m ipykernel install --user --name bayes-econ
# ```

# %%
import pymc as pm
import arviz as az
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import h5py
import statsmodels.api as sm
az.style.use("arviz-white")

# %% [markdown]
# ## Example 0 - 8 schools

# %%
J = 8
y = np.array([28, 8, -3, 7, -1, 1, 18, 12])
# lower std for better visualizations
sigma = np.array([15, 10, 16, 11, 9, 11, 10, 18]) / 2

# %% [markdown]
# $$
# \begin{array}{rcl}
#             \text{mu} &\sim & \operatorname{N}(0,~5)\\\text{tau} &\sim & \operatorname{C^{+}}(0,~5)\\\text{theta}_i &\sim & \operatorname{N}(\text{mu},~\text{tau})\\\text{obs}_i &\sim & \operatorname{N}(\text{theta},~\sigma_i)
#             \end{array}
# $$

# %%
with pm.Model(coords=dict(J=range(J))) as schools_centered:
    mu = pm.Normal("mu", mu=0, sigma=5)
    tau = pm.HalfCauchy("tau", beta=5)
    theta = pm.Normal("theta", mu=mu, sigma=tau, dims="J")
    obs = pm.Normal("obs", mu=theta, sigma=sigma, observed=y)

# %%
pm.model_to_graphviz(schools_centered)

# %%
schools_centered
# Out:
#    mu ~ N(0, 5)
#   tau ~ C**+(0, 5)
# theta ~ N(mu, tau)
#   obs ~ N(theta, <constant>)

# %%
with schools_centered:
    trace = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, tau, theta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:05<00:00 Sampling 4 chains, 79 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 7 seconds.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 13 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.7076, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 7 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 56 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5309, but should be close to 0.8. Try to increase the number of tuning steps.

# %% [markdown]
# ## Example 1 - Where Do Priors Come From?

# %%
data = pd.read_csv(
    "https://osf.io/vfjud/download", 
    sep="\t", 
    names=["id", "QF", "sopt1", "sopt2", "sopt3", "sopt4", "cudit1"], 
    na_values="999"
)

# %%
data
# Out:
#       id    QF    sopt1    sopt2    sopt3    sopt4  cudit1
# 0      1   1.0  75.0000  88.8889  88.8889      NaN       0
# 1      2   0.0      NaN      NaN      NaN      NaN       0
# 2      3   2.0      NaN      NaN      NaN      NaN       0
# 3      4   0.0      NaN      NaN      NaN      NaN       0
# 4      5  14.0      NaN      NaN      NaN      NaN       1
# ..   ...   ...      ...      ...      ...      ...     ...
# 263  186  23.0      NaN      NaN      NaN      NaN       1
# 264  187   3.0  77.7778  83.3333      NaN      NaN       0
# 265  189   0.0  77.7778  83.3333  88.8889  91.6667       0
# 266  190   0.0      NaN      NaN      NaN      NaN       0
# 267  191   0.0      NaN      NaN      NaN      NaN       0
#
# [268 rows x 7 columns]

# %% [markdown]
# > Their "id" variable seem to have duplicates

# %%
long_data = (
    pd.wide_to_long(data.reset_index(), "sopt", "index", "t")
    .reset_index()
    .dropna()
    .assign(t=lambda df: df.t-1)
)
long_data
# Out:
#       index  t   id    QF  cudit1     sopt
# 0         0  0    1   1.0       0  75.0000
# 7         7  0    8   0.0       0  75.0000
# 8         8  0    9   0.0       0  33.3333
# 9         9  0   10   0.0       0  66.6667
# 10       10  0   11   0.0       0  58.3333
# ...     ... ..  ...   ...     ...      ...
# 1056    252  3  175   1.0       0  83.3333
# 1058    254  3  177   0.0       0  61.1111
# 1061    257  3  180  12.0       0  86.1111
# 1064    260  3  183   1.0       0  83.3333
# 1069    265  3  189   0.0       0  91.6667
#
# [666 rows x 6 columns]

# %% [markdown]
# ## Visualizing data

# %%
data.loc[:, "sopt1":"sopt4"].T.plot(legend=False, color="b", alpha=0.2);
avg = data.loc[:, "sopt1":"sopt4"].mean().plot(color="b", linestyle="--", lw=4, label="avg")
plt.title("SOPT scores")
plt.xlabel("Tests 1-4")
plt.ylabel("Score");

# %% [markdown]
# The data is split by "CUDIT" variable which splits heavy and light users

# %%
ax = data.query("cudit1 == 0").loc[:, "sopt1":"sopt4"].T.plot(legend=False, color="blue", alpha=0.2);
data.query("cudit1 == 0").loc[:, "sopt1":"sopt4"].mean().plot(color="blue", linestyle="--", lw=4, label="avg", ax=ax)
data.query("cudit1 == 1").loc[:, "sopt1":"sopt4"].T.plot(legend=False, color="red", alpha=1, ax=ax);
data.query("cudit1 == 1").loc[:, "sopt1":"sopt4"].mean().plot(color="red", linestyle="--", lw=4, label="avg", ax=ax)
plt.title("SOPT scores")
plt.xlabel("Tests 1-4")
plt.ylabel("Score");

# %% [markdown]
# ## The model

# %% [markdown]
# #### Functional form
# $$
# \text{SOPT}_t = a_1 + a_2 * t + a_3 * t ^ 2
# $$
#
# * $a_1$ - intercept
# * $a_2$ - linear trend
# * $a_3$ - quadratic term, possible decay in growth
# * $t$ - $0\dots 3$, periods where measurement was taken

# %% [markdown]
# ### Priors (by Authors)
# $$
# \begin{align}
# \text{SOPT}_t &\sim \operatorname{Normal}(a_1 + a_2 * t + a_3 * t ^ 2, \sigma)\\
# a_1 &\sim \operatorname{Normal}(85, \sqrt{30})\\
# a_2 &\sim \operatorname{Normal}(2, \sqrt{7.5})\\
# a_3 &\sim \operatorname{Normal}(-0.1, \sqrt{7.5})\\
# \sigma &\sim \operatorname{HalfFlat}
# \end{align}
# $$

# %% [markdown]
# > $\sigma$ is the most unclear part of the paper.
# >
# > Authors used MPLUS library whith the following [docs](https://www.rensvandeschoot.com/regression-in-mplus-bayesian/)
# > Which advertises $\sigma \sim \operatorname{I-Gamma}(-1, 0)$.
# >
# > This is HalfFlat distribution (the most obscure choice)

# %% [markdown]
# #### Adding Groups
# Groups are added in a very simplistic way
#
# $$
# \begin{align}
# \text{SOPT}^g_t &\sim \operatorname{Normal}(a^g_1 + a^g_2 * t + a_3 * t ^ 2, \sigma)\\
# a^g_1 &\sim \operatorname{Normal}(85, \sqrt{30})\\
# a^g_2 &\sim \operatorname{Normal}(2, \sqrt{7.5})\\
# a_3 &\sim \operatorname{Normal}(-0.1, \sqrt{7.5})\\
# a^0_2 - a^1_2 &\sim \operatorname{Normal}(0, 10)\\
# \sigma &\sim \operatorname{HalfFlat}
# \end{align}
# $$

# %% [markdown]
# ##### Potential Trick

# %% [markdown]
# You can see a non standard interaction
# $$
# a^0_2 - a^1_2 \sim \operatorname{Normal}(0, 10)
# $$
# With PyMC this can be incorporated into the model with a Potential.

# %%
import itertools
with pm.Model(coords=dict(cudit=["light", "heavy"], period=range(4))) as model:
    # a1 and a2 priors are simple
    # dims="cudit" will notify the model to add extra dims
    a1 = pm.Normal("a1", 85, 30**0.5, dims="cudit")
    # coordinates help in visualizations
    a2 = pm.Normal("a2", 2, 7.5**0.5, dims="cudit")
    
    # the use of the potential (as authors do)
    pm.Potential("diff", pm.logp(pm.Normal.dist(0, 10), a2[1]-a2[0]))
    
    # shared quadratic term
    a3 = pm.Normal("a3", -0.1, 7.5**.5)
    
    # obscure sigma
    σ = pm.HalfFlat("σ")
    # creating a matrix with items (cudit x period)
    estimate = a1[:, None] + a2[:, None] * np.arange(4) + a3 * np.arange(4) ** 2
    estimate = pm.Deterministic("estimate", estimate, dims=["cudit", "period"])
    
    # you can use numpy to get an estimate for each observation
    long_estimate = estimate[long_data.cudit1.values, long_data.t.values]
    
    observed = pm.Normal("observed", long_estimate, σ, observed=long_data.sopt)

# %%
with model:
    trace = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a1, a2, a3, σ]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:09<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 10 seconds.
# The acceptance probability does not match the target. It is 0.8826, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
az.plot_forest(trace)
# Out:
# array([<AxesSubplot:title={'center':'94.0% HDI'}>], dtype=object)

# %%
trace
# Out:
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data

# %%
me = trace.posterior.estimate.mean(["chain", "draw"])
se = trace.posterior.estimate.std(["chain", "draw"])

# %%
df = trace.posterior.estimate.stack(sample=["chain", "draw"]).to_dataframe()

# %%
sns.boxplot(x="period", y="estimate", hue="cudit", data=df.reset_index());

# %% [markdown]
# # Bayesian models

# %% [markdown]
# In this seminar:
#
# * Make sure all the dependencies are installed and work fine for you
# * Look into the lecture example

# %% [markdown]
# ## Installation
# 1. Install [Anaconda](https://www.anaconda.com/) or [Mamba](https://github.com/mamba-org/mamba)
#
#     * Conda is slow
#     * Mamba is fast (I use this one)
#
# 2. Create an environment for the course
#
# ```console
# conda env update -f environment.yaml
# ```
#
# You can find the environment file in the root of the repository
#
# 3. Install jupyter kernel for the course
#
# ```
# conda activate bayes-econ
# python -m ipykernel install --user --name bayes-econ
# ```

# %%
import pymc as pm
import arviz as az
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import h5py
import statsmodels.api as sm
az.style.use("arviz-white")

# %% [markdown]
# ## Example 0 - 8 schools

# %%
J = 8
y = np.array([28, 8, -3, 7, -1, 1, 18, 12])
# lower std for better visualizations
sigma = np.array([15, 10, 16, 11, 9, 11, 10, 18]) / 2

# %% [markdown]
# We'll use
# * `pm.Normal`
# * `pm.HalfCauchy`

# %%
x = np.linspace(0, 10)

# %%
d = pm.HalfCauchy.dist(5)

# %%
logp = pm.logp(d, x)

# %%
import aesara

# %%
plt.plot(np.exp(logp.eval()));

# %% [markdown]
# $$
# \begin{array}{rcl}
#             \text{mu} &\sim & \operatorname{N}(0,~5)\\\text{tau} &\sim & \operatorname{C^{+}}(0,~5)\\\text{theta}_i &\sim & \operatorname{N}(\text{mu},~\text{tau})\\\text{obs}_i &\sim & \operatorname{N}(\text{theta},~\sigma_i)
#             \end{array}
# $$

# %%
with pm.Model(coords=dict(J=range(J))) as schools_centered:
    mu = pm.Normal("mu", mu=0, sigma=5)
    tau = pm.HalfCauchy("tau", beta=5)
    theta = pm.Normal("theta", mu=mu, sigma=tau, dims="J")
    obs = pm.Normal("obs", mu=theta, sigma=sigma, observed=y)

# %%
pm.model_to_graphviz(schools_centered)

# %%
schools_centered
# Out:
#    mu ~ N(0, 5)
#   tau ~ C**+(0, 5)
# theta ~ N(mu, tau)
#   obs ~ N(theta, <constant>)

# %%
with schools_centered:
    trace = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, tau, theta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:05<00:00 Sampling 4 chains, 79 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 7 seconds.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 13 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.7076, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 7 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 56 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5309, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
trace
# Out:
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data

# %%
az.plot_trace(trace, var_names=["theta"], compact=False);

# %% [markdown]
# ## Example 1 - Where Do Priors Come From?

# %%
data = pd.read_csv(
    "https://osf.io/vfjud/download", 
    sep="\t", 
    names=["id", "QF", "sopt1", "sopt2", "sopt3", "sopt4", "cudit1"], 
    na_values="999"
)

# %%
data
# Out:
#       id    QF    sopt1    sopt2    sopt3    sopt4  cudit1
# 0      1   1.0  75.0000  88.8889  88.8889      NaN       0
# 1      2   0.0      NaN      NaN      NaN      NaN       0
# 2      3   2.0      NaN      NaN      NaN      NaN       0
# 3      4   0.0      NaN      NaN      NaN      NaN       0
# 4      5  14.0      NaN      NaN      NaN      NaN       1
# ..   ...   ...      ...      ...      ...      ...     ...
# 263  186  23.0      NaN      NaN      NaN      NaN       1
# 264  187   3.0  77.7778  83.3333      NaN      NaN       0
# 265  189   0.0  77.7778  83.3333  88.8889  91.6667       0
# 266  190   0.0      NaN      NaN      NaN      NaN       0
# 267  191   0.0      NaN      NaN      NaN      NaN       0
#
# [268 rows x 7 columns]

# %% [markdown]
# > Their "id" variable seem to have duplicates

# %%
long_data = (
    pd.wide_to_long(data.reset_index(), "sopt", "index", "t")
    .reset_index()
    .dropna()
    .assign(t=lambda df: df.t-1)
)
long_data
# Out:
#       index  t   id    QF  cudit1     sopt
# 0         0  0    1   1.0       0  75.0000
# 7         7  0    8   0.0       0  75.0000
# 8         8  0    9   0.0       0  33.3333
# 9         9  0   10   0.0       0  66.6667
# 10       10  0   11   0.0       0  58.3333
# ...     ... ..  ...   ...     ...      ...
# 1056    252  3  175   1.0       0  83.3333
# 1058    254  3  177   0.0       0  61.1111
# 1061    257  3  180  12.0       0  86.1111
# 1064    260  3  183   1.0       0  83.3333
# 1069    265  3  189   0.0       0  91.6667
#
# [666 rows x 6 columns]

# %% [markdown]
# ## Visualizing data

# %%
data.loc[:, "sopt1":"sopt4"].T.plot(legend=False, color="b", alpha=0.2);
avg = data.loc[:, "sopt1":"sopt4"].mean().plot(color="b", linestyle="--", lw=4, label="avg")
plt.title("SOPT scores")
plt.xlabel("Tests 1-4")
plt.ylabel("Score");

# %% [markdown]
# The data is split by "CUDIT" variable which splits heavy and light users

# %%
ax = data.query("cudit1 == 0").loc[:, "sopt1":"sopt4"].T.plot(legend=False, color="blue", alpha=0.2);
data.query("cudit1 == 0").loc[:, "sopt1":"sopt4"].mean().plot(color="blue", linestyle="--", lw=4, label="avg", ax=ax)
data.query("cudit1 == 1").loc[:, "sopt1":"sopt4"].T.plot(legend=False, color="red", alpha=1, ax=ax);
data.query("cudit1 == 1").loc[:, "sopt1":"sopt4"].mean().plot(color="red", linestyle="--", lw=4, label="avg", ax=ax)
plt.title("SOPT scores")
plt.xlabel("Tests 1-4")
plt.ylabel("Score");

# %% [markdown]
# ## The model

# %% [markdown]
# #### Functional form
# $$
# \text{SOPT}_t = a_1 + a_2 * t + a_3 * t ^ 2
# $$
#
# * $a_1$ - intercept
# * $a_2$ - linear trend
# * $a_3$ - quadratic term, possible decay in growth
# * $t$ - $0\dots 3$, periods where measurement was taken

# %% [markdown]
# ### Priors (by Authors)
# $$
# \begin{align}
# \text{SOPT}_t &\sim \operatorname{Normal}(a_1 + a_2 * t + a_3 * t ^ 2, \sigma)\\
# a_1 &\sim \operatorname{Normal}(85, \sqrt{30})\\
# a_2 &\sim \operatorname{Normal}(2, \sqrt{7.5})\\
# a_3 &\sim \operatorname{Normal}(-0.1, \sqrt{7.5})\\
# \sigma &\sim \operatorname{HalfFlat}
# \end{align}
# $$

# %% [markdown]
# > $\sigma$ is the most unclear part of the paper.
# >
# > Authors used MPLUS library whith the following [docs](https://www.rensvandeschoot.com/regression-in-mplus-bayesian/)
# > Which advertises $\sigma \sim \operatorname{I-Gamma}(-1, 0)$.
# >
# > This is HalfFlat distribution (the most obscure choice)

# %% [markdown]
# #### Adding Groups
# Groups are added in a very simplistic way
#
# $$
# \begin{align}
# \text{SOPT}^g_t &\sim \operatorname{Normal}(a^g_1 + a^g_2 * t + a_3 * t ^ 2, \sigma)\\
# a^g_1 &\sim \operatorname{Normal}(85, \sqrt{30})\\
# a^g_2 &\sim \operatorname{Normal}(2, \sqrt{7.5})\\
# a_3 &\sim \operatorname{Normal}(-0.1, \sqrt{7.5})\\
# a^0_2 - a^1_2 &\sim \operatorname{Normal}(0, 10)\\
# \sigma &\sim \operatorname{HalfFlat}
# \end{align}
# $$

# %% [markdown]
# ##### Potential Trick

# %% [markdown]
# You can see a non standard interaction
# $$
# a^0_2 - a^1_2 \sim \operatorname{Normal}(0, 10)
# $$
# With PyMC this can be incorporated into the model with a Potential.

# %%
long_data.head()
# Out:
#     index  t  cudit1  id   QF     sopt
# 0       0  0       0   1  1.0  75.0000
# 7       7  0       0   8  0.0  75.0000
# 8       8  0       0   9  0.0  33.3333
# 9       9  0       0  10  0.0  66.6667
# 10     10  0       0  11  0.0  58.3333

# %%
import itertools
with pm.Model(coords=dict(cudit=["light", "heavy"], period=range(4))) as model:
    # a1 and a2 priors are simple
    # dims="cudit" will notify the model to add extra dims
    a1 = pm.Normal("a1", 85, 30**0.5, dims="cudit")
    # coordinates help in visualizations
    a2 = pm.Normal("a2", 2, 7.5**0.5, dims="cudit")
    
    # the use of the potential (as authors do)
    pm.Potential("diff", pm.logp(pm.Normal.dist(0, 10), a2[1]-a2[0]))
    
    # shared quadratic term
    a3 = pm.Normal("a3", -0.1, 7.5**.5)
    
    # obscure sigma
    σ = pm.HalfFlat("σ")
    # creating a matrix with items (cudit x period)
    estimate = a1[:, None] + a2[:, None] * np.arange(4) + a3 * np.arange(4) ** 2
    estimate = pm.Deterministic("estimate", estimate, dims=["cudit", "period"])
    
    # you can use numpy to get an estimate for each observation
    long_estimate = estimate[long_data.cudit1.values, long_data.t.values]
    
    observed = pm.Normal("observed", long_estimate, σ, observed=long_data.sopt)

# %%
with model:
    trace = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a1, a2, a3, σ]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:09<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 10 seconds.
# The acceptance probability does not match the target. It is 0.8826, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
az.plot_trace(trace);

# %%
az.plot_forest(trace)
# Out:
# array([<AxesSubplot:title={'center':'94.0% HDI'}>], dtype=object)

# %%
import xarray as xa

# %%
time = xa.DataArray(np.arange(4), dims="time", name="time")

# %%
trace
# Out:
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data

# %%
cudit
# Out:
# <xarray.DataArray (chain: 4, draw: 1000, cudit: 2, time: 4)>
# array([[[[73.51237643, 76.79217442, 79.09088872, 80.40851934],
#          [72.25243459, 74.96381873, 76.69411918, 77.44333594]],
#
#         [[74.58803792, 78.62409704, 80.50549708, 80.23223803],
#          [74.08615658, 75.91550685, 75.59019802, 73.11023012]],
#
#         [[72.73164359, 77.35355769, 79.85255369, 80.22863159],
#          [73.18605908, 77.45238886, 79.59580054, 79.61629411]],
#
#         ...,
#
#         [[72.98868085, 76.74197908, 79.4211648 , 81.026238  ],
#          [75.19350315, 76.65885051, 77.05008535, 76.36720769]],
#
#         [[75.38503573, 78.71799371, 79.97256957, 79.14876331],
#          [72.93123312, 74.19302517, 73.3764351 , 70.48146291]],
#
#         [[74.36462887, 78.13992559, 80.25382233, 80.70631909],
#          [73.71046544, 76.28125601, 77.19064659, 76.43863719]]],
#
# ...
#
#        [[[73.54451788, 77.37975803, 78.72858895, 77.59101062],
#          [71.07604131, 75.11455695, 76.66666334, 75.7323605 ]],
#
#         [[73.25658486, 77.55376036, 79.79331823, 79.97525848],
#          [77.82862765, 78.72051392, 77.55478256, 74.33143358]],
#
#         [[73.50302441, 77.48332214, 79.46120978, 79.43668731],
#          [79.58197184, 80.0657325 , 78.54708305, 75.0260235 ]],
#
#         ...,
#
#         [[73.50526307, 78.04292316, 79.69153998, 78.45111354],
#          [74.98166563, 76.92398677, 75.97726464, 72.14149924]],
#
#         [[73.53707366, 77.0549902 , 78.56575819, 78.06937765],
#          [74.06169058, 77.50069454, 78.93254995, 78.35725681]],
#
#         [[74.07606324, 77.73070774, 79.58861246, 79.64977739],
#          [75.47274355, 75.51500567, 73.760528  , 70.20931055]]]])
# Coordinates:
#   * chain    (chain) int64 0 1 2 3
#   * draw     (draw) int64 0 1 2 3 4 5 6 7 8 ... 992 993 994 995 996 997 998 999
#   * cudit    (cudit) <U5 'light' 'heavy'
# Dimensions without coordinates: time

# %%
cudit.stack(sample=["chain", "draw"]).to_dataframe(name="y")
# Out:
#                                y
# cudit time chain draw
# light 0    0     0     73.512376
#                  1     74.588038
#                  2     72.731644
#                  3     73.955622
#                  4     74.565300
# ...                          ...
# heavy 3    3     995   75.987121
#                  996   74.418816
#                  997   72.141499
#                  998   78.357257
#                  999   70.209311
#
# [32000 rows x 1 columns]

# %%
df = trace.posterior.estimate.stack(sample=["chain", "draw"]).to_dataframe()

# %%
df.reset_index()
# Out:
#        cudit  time  chain  draw          y
# 0      light     0      0     0  73.512376
# 1      light     0      0     1  74.588038
# 2      light     0      0     2  72.731644
# 3      light     0      0     3  73.955622
# 4      light     0      0     4  74.565300
# ...      ...   ...    ...   ...        ...
# 31995  heavy     3      3   995  75.987121
# 31996  heavy     3      3   996  74.418816
# 31997  heavy     3      3   997  72.141499
# 31998  heavy     3      3   998  78.357257
# 31999  heavy     3      3   999  70.209311
#
# [32000 rows x 5 columns]

# %%
sns.boxplot(x="period", y="estimate", hue="cudit", data=df.reset_index());
